# %%
import pandas as pd
import tqdm
import requests
from bs4 import BeautifulSoup
from concurrent.futures import ThreadPoolExecutor

# %%
# read csv file
df = pd.read_csv('../data/raw/cricsheet/people.csv')

# drop columns
df = df.drop(columns=['key_bcci', 'key_bcci_2',
       'key_bigbash', 'key_cricbuzz', 'key_cricheroes', 'key_crichq', 'key_cricingif', 'key_cricketarchive',
       'key_cricketarchive_2', 'key_cricketworld', 'key_nvplay',
       'key_nvplay_2', 'key_opta', 'key_opta_2', 'key_pulse', 'key_pulse_2'])

df
# Out:
#       identifier                name            unique_name  key_cricinfo  \
# 0       b4a23876       AAA Amsterdam          AAA Amsterdam      772407.0
# 1       482762af           AA Adeoye              AA Adeoye      380588.0
# 2       4b0e3049          AA Alleyne             AA Alleyne      661441.0
# 3       fd3c5c00           AAA Patel              AAA Patel     1163136.0
# 4       bc005f0d           AAA White              AAA White      474307.0
# ...          ...                 ...                    ...           ...
# 15867   ee9bdbc8   Zulqarnain Haider      Zulqarnain Haider       43860.0
# 15868   2d46e8ed   Zulqarnain Haider  Zulqarnain Haider (2)     1046641.0
# 15869   b71670a0  Zulufat Mutoniwase     Zulufat Mutoniwase     1380564.0
# 15870   d35c1fc7         Zumika Azmi            Zumika Azmi     1050037.0
# 15871   78a3ae4b         ZXM Vukusic            ZXM Vukusic     1442092.0
#
#        key_cricinfo_2
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 15867             NaN
# 15868             NaN
# 15869             NaN
# 15870             NaN
# 15871             NaN
#
# [15872 rows x 5 columns]

# %%
# check if key_cricinfo is unique
print(df['key_cricinfo'].is_unique)

# change rows with NaN to -1
df['key_cricinfo'] = df['key_cricinfo'].fillna(-1)
df['key_cricinfo_2'] = df['key_cricinfo_2'].fillna(-1)

# make key_cricinfo integer
df['key_cricinfo'] = df['key_cricinfo'].astype(int)
df['key_cricinfo_2'] = df['key_cricinfo_2'].astype(int)
# Out:
# False

# %%
# link to scrap data from cricinfo:  https://www.espncricinfo.com/ci/content/player/{}.html
url = 'https://www.espncricinfo.com/ci/content/player/{}.html'

def get_image_url(soup, id):
    images = soup.find_all('img')
    try:
        img = [image['src'] for image in images if 'upload' in image['src']][0]
    except:
        img = 'https://wassets.hscicdn.com/static/images/lazyimage-transparent.png'
        print('No image found for this player {}'.format(id))
    return img

def save_image(url, filename):
    if url is None:
        return
    response = requests.get(url)
    with open(filename, 'wb') as file:
        file.write(response.content)

# %%
def process_row(row):
    if row['key_cricinfo'] == -1:
        save_image('https://wassets.hscicdn.com/static/images/lazyimage-transparent.png', 'images/{}-{}.jpg'.format(row['identifier'], row['name']))
    response = requests.get(url.format(row['key_cricinfo']))
    soup = BeautifulSoup(response.text, 'html.parser')
    img = get_image_url(soup, row['key_cricinfo'])
    save_image(img, 'images/{}-{}.jpg'.format(row['identifier'], row['name']))

# %%
with ThreadPoolExecutor(max_workers=4) as executor:
    list(tqdm.tqdm(executor.map(process_row, [row for _, row in df.iloc[1000:].iterrows()]), total=df.shape[0]))

# %%
# give the row where name is 'Rohit Sharma'
print(df[df['name'] == 'RG Sharma'])

# %%
save_image('https://wassets.hscicdn.com/static/images/lazyimage-transparent.png', 'image.jpg')

# %%
# calculate the percentage of images in the folder which are the same as image.jpg 8256
import os
import cv2
import numpy as np

def compare_images(image1, image2):
    img1 = cv2.imread(image1)
    img2 = cv2.imread(image2)
    if img1 is None or img2 is None:
        return 0
    return np.array_equal(img1, img2)

images = os.listdir('images')
print(len(images))
count = 0
for image in tqdm.tqdm(images):
    if compare_images('image.jpg', 'images/{}'.format(image)):
        # remove the image
        # os.remove('images/{}'.format(image))
        count += 1
print(count/len(images)*100, count, len(images))

# %%
url = 'https://www.espncricinfo.com/ci/content/player/{}.html'

# id = df[df['name'] == 'RG Sharma']['key_cricinfo'].values[0]
# soup = BeautifulSoup(requests.get(url.format(id)).text, 'html.parser')
# # get all paragraphs
# paragraphs = soup.find_all('p')

# get full name, Batting style, Bowling style, Playing role
def get_data(paragraphs, data, id):
    try:
        p_index = [i for i, p in enumerate(paragraphs) if data in p.text][0]
        res = paragraphs[p_index+1].text
    except IndexError:
        # print('No data found for this player {} for {}'.format(id, data))
        res = None
    return res

# %%
# make a new dataframe with the above data for each player along with identifier column
data = []
a = 0
not_found = 0
def process_row_data(row):
    global a, data, not_found
    id = row['key_cricinfo']
    if id == -1:
        data.append([row['identifier'], 'Not Found', 'Not Found', 'Not Found', 'Not Found'])
        a += 1
        not_found += 1
        return
    soup = BeautifulSoup(requests.get(url.format(id)).text, 'html.parser')
    paragraphs = soup.find_all('p')
    full_name = get_data(paragraphs, 'Full Name', id)
    batting_style = get_data(paragraphs, 'Batting Style', id)
    bowling_style = get_data(paragraphs, 'Bowling Style' , id)
    playing_role = get_data(paragraphs, 'Playing Role' , id)
    data.append([row['identifier'], full_name, batting_style, bowling_style, playing_role])
    a += 1
    if a % 100 == 0:
        print("Processed {} rows".format(a))

# %%
with ThreadPoolExecutor(max_workers=8) as executor:
    list(executor.map(process_row_data, [row for _, row in df.iterrows()]))
# Out:
# Processed 100 rows
# Processed 200 rows
# Processed 300 rows
# Processed 400 rows
# Processed 600 rows
# Processed 700 rows
# Processed 800 rows
# Processed 900 rows
# Processed 1000 rows
# Processed 1100 rows
# Processed 1200 rows
# Processed 1300 rows
# Processed 1400 rows
# Processed 1500 rows
# Processed 1600 rows
# Processed 1700 rows
# Processed 1800 rows
# Processed 1900 rows
# Processed 2000 rows
# Processed 2100 rows
# Processed 2200 rows
# Processed 2300 rows
# Processed 2400 rows
# Processed 2500 rows
# Processed 2600 rows
# Processed 2700 rows
# Processed 2800 rows
# Processed 2900 rows
# Processed 3000 rows
# Processed 3100 rows
# Processed 3200 rows
# Processed 3300 rows
# Processed 3400 rows
# Processed 3500 rows
# Processed 3600 rows
# Processed 3700 rows
# Processed 3800 rows
# Processed 3900 rows
# Processed 4000 rows
# Processed 4100 rows
# Processed 4200 rows
# Processed 4300 rows
# Processed 4400 rows
# Processed 4500 rows
# Processed 4600 rows
# Processed 4700 rows
# Processed 4800 rows
# Processed 4900 rows
# Processed 5000 rows
# Processed 5100 rows
# Processed 5200 rows
# Processed 5300 rows
# Processed 5400 rows
# Processed 5500 rows
# Processed 5600 rows
# Processed 5700 rows
# Processed 5800 rows
# Processed 5900 rows
# Processed 6000 rows
# Processed 6100 rows
# Processed 6200 rows
# Processed 6300 rows
# Processed 6400 rows
# Processed 6500 rows
# Processed 6600 rows
# Processed 6700 rows
# Processed 6800 rows
# Processed 6900 rows
# Processed 7000 rows
# Processed 7100 rows
# Processed 7200 rows
# Processed 7300 rows
# Processed 7400 rows
# Processed 7500 rows
# Processed 7600 rows
# Processed 7700 rows
# Processed 7800 rows
# Processed 7900 rows
# Processed 8000 rows
# Processed 8100 rows
# Processed 8200 rows
# Processed 8300 rows
# Processed 8400 rows
# Processed 8500 rows
# Processed 8600 rows
# Processed 8700 rows
# Processed 8800 rows
# Processed 8900 rows
# Processed 9000 rows
# Processed 9100 rows
# Processed 9200 rows
# Processed 9300 rows
# Processed 9400 rows
# Processed 9500 rows
# Processed 9600 rows
# Processed 9700 rows
# Processed 9800 rows
# Processed 9900 rows
# Processed 10000 rows
# Processed 10100 rows
# Processed 10200 rows
# Processed 10300 rows
# Processed 10400 rows
# Processed 10500 rows
# Processed 10600 rows
# Processed 10700 rows
# Processed 10800 rows
# Processed 10900 rows
# Processed 11000 rows
# Processed 11100 rows
# Processed 11200 rows
# Processed 11300 rows
# Processed 11400 rows
# Processed 11500 rows
# Processed 11600 rows
# Processed 11700 rows
# Processed 11800 rows
# Processed 11900 rows
# Processed 12000 rows
# Processed 12100 rows
# Processed 12200 rows
# Processed 12300 rows
# Processed 12400 rows
# Processed 12500 rows
# Processed 12600 rows
# Processed 12700 rows
# Processed 12800 rows
# Processed 12900 rows
# Processed 13000 rows
# Processed 13100 rows
# Processed 13200 rows
# Processed 13300 rows
# Processed 13400 rows
# Processed 13500 rows
# Processed 13600 rows
# Processed 13700 rows
# Processed 13800 rows
# Processed 13900 rows
# Processed 14000 rows
# Processed 14100 rows
# Processed 14200 rows
# Processed 14300 rows
# Processed 14400 rows
# Processed 14500 rows
# Processed 14600 rows
# Processed 14700 rows
# Processed 14800 rows
# Processed 14900 rows
# Processed 15000 rows
# Processed 15100 rows
# Processed 15200 rows
# Processed 15300 rows
# Processed 15400 rows
# Processed 15500 rows
# Processed 15600 rows
# Processed 15700 rows
# Processed 15800 rows
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 with ThreadPoolExecutor(max_workers=8) as executor:
# ----> 2     list(executor.map(process_row_data, [row for _, row in df.iterrows()]))
#
# File /usr/lib/python3.10/concurrent/futures/_base.py:621, in Executor.map.<locals>.result_iterator()
#     620 if timeout is None:
# --> 621     yield _result_or_cancel(fs.pop())
#     622 else:
#
# File /usr/lib/python3.10/concurrent/futures/_base.py:319, in _result_or_cancel(***failed resolving arguments***)
#     318 try:
# --> 319     return fut.result(timeout)
#     320 finally:
#
# File /usr/lib/python3.10/concurrent/futures/_base.py:453, in Future.result(self, timeout)
#     451     return self.__get_result()
# --> 453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /usr/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     319 if timeout is None:
# --> 320     waiter.acquire()
#     321     gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 with ThreadPoolExecutor(max_workers=8) as executor:
#       2     list(executor.map(process_row_data, [row for _, row in df.iterrows()]))
#
# File /usr/lib/python3.10/concurrent/futures/_base.py:649, in Executor.__exit__(self, exc_type, exc_val, exc_tb)
#     648 def __exit__(self, exc_type, exc_val, exc_tb):
# --> 649     self.shutdown(wait=True)
#     650     return False
#
# File /usr/lib/python3.10/concurrent/futures/thread.py:235, in ThreadPoolExecutor.shutdown(self, wait, cancel_futures)
#     233 if wait:
#     234     for t in self._threads:
# --> 235         t.join()
#
# File /usr/lib/python3.10/threading.py:1096, in Thread.join(self, timeout)
#    1093     raise RuntimeError("cannot join current thread")
#    1095 if timeout is None:
# -> 1096     self._wait_for_tstate_lock()
#    1097 else:
#    1098     # the behavior of a negative timeout isn't documented, but
#    1099     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1100     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File /usr/lib/python3.10/threading.py:1116, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1113     return
#    1115 try:
# -> 1116     if lock.acquire(block, timeout):
#    1117         lock.release()
#    1118         self._stop()
#
# KeyboardInterrupt:

# %%
print(len(data),df.shape[0])
# remove duplicate rows in data
s = [list(x) for x in set(tuple(x) for x in data)]
len(s)
# Out:
# 15872 15872
# 15872

# %%
df1 = pd.DataFrame(data, columns=['identifier', 'full_name', 'batting_style', 'bowling_style', 'playing_role'])
df1.to_csv('../data/raw/additional_data/player_data.csv', index=False)
df1
# Out:
#       identifier                      full_name   batting_style  \
# 0       bc005f0d     Aneka Akeilia Aresha White  Right hand Bat
# 1       5c67c7a6                  Azam Ali Baig            None
# 2       6a58e069                     Arun Bamal   Left hand Bat
# 3       b4a23876  Alex Adrian Anthony Amsterdam   Left hand Bat
# 4       482762af               Adewale A Adeoye  Right hand Bat
# ...          ...                            ...             ...
# 15867   ee9bdbc8              Zulqarnain Haider  Right hand Bat
# 15868   d35c1fc7                    Zumika Azmi  Right hand Bat
# 15869   78a3ae4b     Zach Xavier Meikle Vukusic  Right hand Bat
# 15870   2b203501       Akhil Arjunan Saraladevi  Right hand Bat
# 15871   2feb5b8d                    Akhil Kumar  Right hand Bat
#
#                 bowling_style         playing_role
# 0            Right arm Medium                 None
# 1                        None                 None
# 2      Slow Left arm Orthodox   Bowling Allrounder
# 3          Right arm Offbreak     Top order Batter
# 4            Right arm Medium                 None
# ...                       ...                  ...
# 15867                    None  Wicketkeeper Batter
# 15868      Right arm Offbreak                 None
# 15869        Right arm Medium                 None
# 15870                Legbreak                 None
# 15871   Right arm Medium fast                 None
#
# [15872 rows x 5 columns]

# %%
# check which identifier from df is not in df1
l = []
for i in df['identifier']:
    if i not in df1['identifier'].values:
        print(i)
        l.append(i)

# %%
process_row_data(df[df['identifier'] == l[0]].iloc[0])

# %%
identifiers_with_no_full_name = []
for row in df1.iterrows():
    if row[1]['full_name'] == None:
        identifiers_with_no_full_name.append(row[1]['identifier'])

data_2 = []

def process_row_data_2(row):
    global data_2
    id = row['key_cricinfo_2']
    if id == -1:
        print('No data found for this player {} for key_cricinfo_2 {} key_cricinfo {}'.format(row['identifier'], id, row['key_cricinfo']))
        data_2.append([row['identifier'], None, None, None, None])
        return
    soup = BeautifulSoup(requests.get(url.format(id)).text, 'html.parser')
    paragraphs = soup.find_all('p')
    full_name = get_data(paragraphs, 'Full Name', id)
    batting_style = get_data(paragraphs, 'Batting Style', id)
    bowling_style = get_data(paragraphs, 'Bowling Style' , id)
    playing_role = get_data(paragraphs, 'Playing Role' , id)
    data_2.append([row['identifier'], full_name, batting_style, bowling_style, playing_role])

# %%
for _, row in df[df['identifier'].isin(identifiers_with_no_full_name)].iterrows():
    process_row_data_2(row)
# Out:
# No data found for this player 4095f16b for key_cricinfo_2 -1 key_cricinfo -1
# No data found for this player 2a5ca58b for key_cricinfo_2 -1 key_cricinfo -1
# No data found for this player 7be2bafa for key_cricinfo_2 -1 key_cricinfo -1
# No data found for this player f315f713 for key_cricinfo_2 -1 key_cricinfo -1
# No data found for this player 56d0ab23 for key_cricinfo_2 -1 key_cricinfo 1156633
# No data found for this player 2475b98f for key_cricinfo_2 -1 key_cricinfo -1
# No data found for this player c65e0275 for key_cricinfo_2 -1 key_cricinfo -1
# No data found for this player 7725cb8a for key_cricinfo_2 -1 key_cricinfo -1
# No data found for this player b77d2322 for key_cricinfo_2 -1 key_cricinfo -1
# No data found for this player 543b2173 for key_cricinfo_2 -1 key_cricinfo -1
# No data found for this player 75a667c0 for key_cricinfo_2 -1 key_cricinfo -1
# No data found for this player 6eb27d55 for key_cricinfo_2 -1 key_cricinfo -1
# No data found for this player d0a98a96 for key_cricinfo_2 -1 key_cricinfo 1190595
# No data found for this player 67b5bb60 for key_cricinfo_2 -1 key_cricinfo 575109
# No data found for this player 730b7515 for key_cricinfo_2 -1 key_cricinfo -1
# No data found for this player 1d5978b9 for key_cricinfo_2 -1 key_cricinfo -1
# No data found for this player 41d3085d for key_cricinfo_2 -1 key_cricinfo -1
# No data found for this player c122ab7f for key_cricinfo_2 -1 key_cricinfo -1
# No data found for this player 698dfeae for key_cricinfo_2 -1 key_cricinfo -1
# No data found for this player 2864ee42 for key_cricinfo_2 -1 key_cricinfo 637304
# No data found for this player 0ab90734 for key_cricinfo_2 -1 key_cricinfo -1
# No data found for this player 4083414c for key_cricinfo_2 -1 key_cricinfo -1
# No data found for this player 9130246b for key_cricinfo_2 -1 key_cricinfo -1
# No data found for this player 4dae1243 for key_cricinfo_2 -1 key_cricinfo -1
# No data found for this player 2b44df20 for key_cricinfo_2 -1 key_cricinfo -1
# No data found for this player 1dd91614 for key_cricinfo_2 -1 key_cricinfo -1
# No data found for this player 632fbfbc for key_cricinfo_2 -1 key_cricinfo -1
# No data found for this player 7ea8f69b for key_cricinfo_2 -1 key_cricinfo -1
# No data found for this player 1bea9a5b for key_cricinfo_2 -1 key_cricinfo -1
# No data found for this player 55ed4228 for key_cricinfo_2 -1 key_cricinfo -1
# No data found for this player 71f7d784 for key_cricinfo_2 -1 key_cricinfo -1
# No data found for this player 14b38bfe for key_cricinfo_2 -1 key_cricinfo 1080346
# No data found for this player 83037aab for key_cricinfo_2 -1 key_cricinfo -1
# No data found for this player 2414ac8b for key_cricinfo_2 -1 key_cricinfo -1
# No data found for this player 83d01793 for key_cricinfo_2 -1 key_cricinfo -1
# No data found for this player 49db97e8 for key_cricinfo_2 -1 key_cricinfo -1
# No data found for this player 1c918138 for key_cricinfo_2 -1 key_cricinfo -1
# No data found for this player 35cc7033 for key_cricinfo_2 -1 key_cricinfo -1
# No data found for this player f4b0f3cb for key_cricinfo_2 -1 key_cricinfo -1
# No data found for this player 05273929 for key_cricinfo_2 -1 key_cricinfo -1
# No data found for this player 18af8582 for key_cricinfo_2 -1 key_cricinfo -1
# No data found for this player a5aad500 for key_cricinfo_2 -1 key_cricinfo -1
# No data found for this player bdc91516 for key_cricinfo_2 -1 key_cricinfo -1
# No data found for this player c54d75a3 for key_cricinfo_2 -1 key_cricinfo -1
# No data found for this player dcc12ed6 for key_cricinfo_2 -1 key_cricinfo -1
# No data found for this player d871bec5 for key_cricinfo_2 -1 key_cricinfo -1
# No data found for this player 2edeafa1 for key_cricinfo_2 -1 key_cricinfo -1
# No data found for this player 9f3263f4 for key_cricinfo_2 -1 key_cricinfo -1
# No data found for this player 423cd1f2 for key_cricinfo_2 -1 key_cricinfo -1

# %%
# replace data_2 in df1 according to identifier
data_og = data
for i in range(len(data_2)):
    for j in range(len(data_og)):
        if data_2[i][0] == data_og[j][0]:
            data_og[j] = data_2[i]

df1 = pd.DataFrame(data_og, columns=['identifier', 'full_name', 'batting_style', 'bowling_style', 'playing_role'])
df1.to_csv('../data/raw/additional_data/player_data.csv', index=False)
df1
# Out:
#       identifier                      full_name   batting_style  \
# 0       bc005f0d     Aneka Akeilia Aresha White  Right hand Bat
# 1       5c67c7a6                  Azam Ali Baig            None
# 2       6a58e069                     Arun Bamal   Left hand Bat
# 3       b4a23876  Alex Adrian Anthony Amsterdam   Left hand Bat
# 4       482762af               Adewale A Adeoye  Right hand Bat
# ...          ...                            ...             ...
# 15867   ee9bdbc8              Zulqarnain Haider  Right hand Bat
# 15868   d35c1fc7                    Zumika Azmi  Right hand Bat
# 15869   78a3ae4b     Zach Xavier Meikle Vukusic  Right hand Bat
# 15870   2b203501       Akhil Arjunan Saraladevi  Right hand Bat
# 15871   2feb5b8d                    Akhil Kumar  Right hand Bat
#
#                 bowling_style         playing_role
# 0            Right arm Medium                 None
# 1                        None                 None
# 2      Slow Left arm Orthodox   Bowling Allrounder
# 3          Right arm Offbreak     Top order Batter
# 4            Right arm Medium                 None
# ...                       ...                  ...
# 15867                    None  Wicketkeeper Batter
# 15868      Right arm Offbreak                 None
# 15869        Right arm Medium                 None
# 15870                Legbreak                 None
# 15871   Right arm Medium fast                 None
#
# [15872 rows x 5 columns]
